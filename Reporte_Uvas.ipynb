# %%
line_to_run= '''python -m nbconvert --to html --no-input "Reporte_Uvas.ipynb" --log-level CRITICAL
#python -m nbconvert --to webpdf --no-input "Reporte_Uvas.ipynb" --TagRemovePreprocessor.enabled=True --PDFExporter.latex_command="['pdflatex', '{filename}', '--landscape']" '''
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="text-align:center; margin-top:20px; margin-bottom:10px;">
#     <img src="Blossom Fruit Logo.PNG " alt="Blossom Fruit Logo" style="width:800px; max-width:90%;"/>
# </div>
#
# <h1 style="text-align:center; font-size:32px;">
#     Blossom Fruit International United States Weekly Grape Imports Analysis
# </h1>

# %%
import pandas as pd
master=pd.read_csv(r"C:\Users\artuv\OneDrive\Bases_Chile_y_UvasPeru\Master.csv")
master.rename(columns={'Dep_Week': 'Departure Week'},inplace=True)
master['Export Country']=master['Year Country'].str.split('-').str[1]

# %%
usa = master[(master['Country']=='U.S.A.') & (master['Specie']=='TABLE GRAPE')]
yearmax = usa['Year'].max()
weekmax = usa[usa['Year']==yearmax]['Departure Week'].max()
for i, row in usa.iterrows():
    w = row['Departure Week']
    y = row['Year']

    if ((w >= 40) and (y >= 2025)):
        usa.at[i, 'Season'] = '2025-2026'
    elif ((w >= 40) and (y == 2024)) or ((w <= 39) and (y == 2025)):
        usa.at[i, 'Season'] = '2024-2025'
    elif ((w >= 40) and (y == 2023)) or ((w <= 39) and (y == 2024)):
        usa.at[i, 'Season'] = '2023-2024'
    else:
        usa.at[i, 'Season'] = '2022-2023'

# %%
season_week=[]
for i in usa['Departure Week']:
    if i<40:
        season_week.append(i+13)
    else:
        season_week.append(i-39)
usa['Season Week']=season_week
usa=usa[usa['Season'].isin(['2023-2024','2024-2025','2025-2026'])]
x=usa.groupby(['Season Week','Season','Market']).agg({'Boxes':'sum'}).reset_index()

# %%
current_week=4
if ((current_week>0)&(current_week<14)):
    adjustment= 39
elif ((current_week>13)&(current_week<40)):
    adjustment= -13

# %% [markdown]
# ## Weekly Imports of Chilean and Peruvian Grapes per Coast (Boxes)

# %%
# Step 2: all unique seasons sorted
seasons = sorted(x['Season'].unique(),reverse=True)

# Step 3: build and merge pivots with totals in between
merged = None

for s in seasons:
    # pivot for this season
    temp = x[x['Season'] == s]
    pivot = temp.pivot_table(
        index='Season Week',
        columns='Market',
        values='Boxes',
        aggfunc='sum'
    ).fillna(0)

    # add a total column for this season
    pivot['TOTAL'] = pivot.sum(axis=1)

    # add season level to all columns
    pivot.columns = pd.MultiIndex.from_product([[s], pivot.columns])

    # merge with previous seasons
    if merged is None:
        merged = pivot
    else:
        merged = merged.join(pivot, how='outer')

# Assume your pivot DataFrame is called merged
# and its index represents numeric Departure Weeks
# Ensure the index is numeric and sorted
merged.index = pd.to_numeric(merged.index, errors='coerce')
merged = merged.sort_index()
idx = merged.index

# 1️⃣ Current week only
current = merged.loc[idx == current_week].sum().to_frame().T
current.index = [f'Week {current_week + adjustment}']

# 2️⃣ Previous 4 (including current)
prev_4 = merged.loc[(idx >= current_week - 3) & (idx <= current_week)].sum().to_frame().T
prev_4.index = ['Previous 4 Weeks Aggregate Total']

# 3️⃣ Previous 8 (including current)
prev_8 = merged.loc[(idx >= current_week - 7) & (idx <= current_week)].sum().to_frame().T
prev_8.index = ['Previous 8  Weeks Aggregate Total']

# 4️⃣ Season to Date (week 1 through current)
ytd = merged.loc[(idx <= current_week)].sum().to_frame().T
ytd.index = ['Season Totals to Date']

# Combine them in order
summary = pd.concat([current, prev_4, prev_8, ytd])
summary = summary.fillna(0).astype(int)

summary.style.format("{:,}").set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'center')]},
    {'selector': 'td', 'props': [('text-align', 'center')]}
]).set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_c486a th {
#   text-align: center;
# }
# #T_c486a td {
#   text-align: center;
# }
# #T_c486a_row0_col0, #T_c486a_row0_col1, #T_c486a_row0_col2, #T_c486a_row0_col3, #T_c486a_row0_col4, #T_c486a_row0_col5, #T_c486a_row0_col6, #T_c486a_row0_col7, #T_c486a_row0_col8, #T_c486a_row1_col0, #T_c486a_row1_col1, #T_c486a_row1_col2, #T_c486a_row1_col3, #T_c486a_row1_col4, #T_c486a_row1_col5, #T_c486a_row1_col6, #T_c486a_row1_col7, #T_c486a_row1_col8, #T_c486a_row2_col0, #T_c486a_row2_col1, #T_c486a_row2_col2, #T_c486a_row2_col3, #T_c486a_row2_col4, #T_c486a_row2_col5, #T_c486a_row2_col6, #T_c486a_row2_col7, #T_c486a_row2_col8, #T_c486a_row3_col0, #T_c486a_row3_col1, #T_c486a_row3_col2, #T_c486a_row3_col3, #T_c486a_row3_col4, #T_c486a_row3_col5, #T_c486a_row3_col6, #T_c486a_row3_col7, #T_c486a_row3_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_c486a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c486a_level0_col0" class="col_heading level0 col0" colspan="3">2025-2026</th>
#       <th id="T_c486a_level0_col3" class="col_heading level0 col3" colspan="3">2024-2025</th>
#       <th id="T_c486a_level0_col6" class="col_heading level0 col6" colspan="3">2023-2024</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Market</th>
#       <th id="T_c486a_level1_col0" class="col_heading level1 col0" >USA EAST COAST</th>
#       <th id="T_c486a_level1_col1" class="col_heading level1 col1" >USA WEST COAST</th>
#       <th id="T_c486a_level1_col2" class="col_heading level1 col2" >TOTAL</th>
#       <th id="T_c486a_level1_col3" class="col_heading level1 col3" >USA EAST COAST</th>
#       <th id="T_c486a_level1_col4" class="col_heading level1 col4" >USA WEST COAST</th>
#       <th id="T_c486a_level1_col5" class="col_heading level1 col5" >TOTAL</th>
#       <th id="T_c486a_level1_col6" class="col_heading level1 col6" >USA EAST COAST</th>
#       <th id="T_c486a_level1_col7" class="col_heading level1 col7" >USA WEST COAST</th>
#       <th id="T_c486a_level1_col8" class="col_heading level1 col8" >TOTAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c486a_level0_row0" class="row_heading level0 row0" >Week 43</th>
#       <td id="T_c486a_row0_col0" class="data row0 col0" >446,640</td>
#       <td id="T_c486a_row0_col1" class="data row0 col1" >96,074</td>
#       <td id="T_c486a_row0_col2" class="data row0 col2" >542,714</td>
#       <td id="T_c486a_row0_col3" class="data row0 col3" >553,210</td>
#       <td id="T_c486a_row0_col4" class="data row0 col4" >101,644</td>
#       <td id="T_c486a_row0_col5" class="data row0 col5" >654,854</td>
#       <td id="T_c486a_row0_col6" class="data row0 col6" >1,081,817</td>
#       <td id="T_c486a_row0_col7" class="data row0 col7" >138,518</td>
#       <td id="T_c486a_row0_col8" class="data row0 col8" >1,220,335</td>
#     </tr>
#     <tr>
#       <th id="T_c486a_level0_row1" class="row_heading level0 row1" >Previous 4 Weeks Aggregate Total</th>
#       <td id="T_c486a_row1_col0" class="data row1 col0" >742,623</td>
#       <td id="T_c486a_row1_col1" class="data row1 col1" >144,193</td>
#       <td id="T_c486a_row1_col2" class="data row1 col2" >886,816</td>
#       <td id="T_c486a_row1_col3" class="data row1 col3" >899,606</td>
#       <td id="T_c486a_row1_col4" class="data row1 col4" >176,649</td>
#       <td id="T_c486a_row1_col5" class="data row1 col5" >1,076,255</td>
#       <td id="T_c486a_row1_col6" class="data row1 col6" >3,148,985</td>
#       <td id="T_c486a_row1_col7" class="data row1 col7" >331,100</td>
#       <td id="T_c486a_row1_col8" class="data row1 col8" >3,480,085</td>
#     </tr>
#     <tr>
#       <th id="T_c486a_level0_row2" class="row_heading level0 row2" >Previous 8  Weeks Aggregate Total</th>
#       <td id="T_c486a_row2_col0" class="data row2 col0" >742,623</td>
#       <td id="T_c486a_row2_col1" class="data row2 col1" >144,193</td>
#       <td id="T_c486a_row2_col2" class="data row2 col2" >886,816</td>
#       <td id="T_c486a_row2_col3" class="data row2 col3" >899,606</td>
#       <td id="T_c486a_row2_col4" class="data row2 col4" >176,649</td>
#       <td id="T_c486a_row2_col5" class="data row2 col5" >1,076,255</td>
#       <td id="T_c486a_row2_col6" class="data row2 col6" >3,148,985</td>
#       <td id="T_c486a_row2_col7" class="data row2 col7" >331,100</td>
#       <td id="T_c486a_row2_col8" class="data row2 col8" >3,480,085</td>
#     </tr>
#     <tr>
#       <th id="T_c486a_level0_row3" class="row_heading level0 row3" >Season Totals to Date</th>
#       <td id="T_c486a_row3_col0" class="data row3 col0" >742,623</td>
#       <td id="T_c486a_row3_col1" class="data row3 col1" >144,193</td>
#       <td id="T_c486a_row3_col2" class="data row3 col2" >886,816</td>
#       <td id="T_c486a_row3_col3" class="data row3 col3" >899,606</td>
#       <td id="T_c486a_row3_col4" class="data row3 col4" >176,649</td>
#       <td id="T_c486a_row3_col5" class="data row3 col5" >1,076,255</td>
#       <td id="T_c486a_row3_col6" class="data row3 col6" >3,148,985</td>
#       <td id="T_c486a_row3_col7" class="data row3 col7" >331,100</td>
#       <td id="T_c486a_row3_col8" class="data row3 col8" >3,480,085</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <small><sup>*</sup>Week 1 is the calender week 40 every year. i.e. Week 40= Week 1, Week 41= Week 2 etc.
#
# *If the current week is less than 4, and or 8 the respective totals will reflect only the season totals, the aggregate are not inclusive of previous seasons.</small>

# %% [markdown]
# ## Imports per Coast by Country of Origin (Boxes)

# %%
y= usa.groupby(['Season Week','Season','Market','Export Country']).agg({'Boxes':'sum'}).reset_index()

# %%
# 1️⃣ Build merged_y
seasons = sorted(y['Season'].unique(),reverse=True)
merged_y = None

for s in seasons:
    temp = y[y['Season'] == s]

    # Pivot by market and export country
    pivot = temp.pivot_table(
        index='Season Week',
        columns=['Market', 'Export Country'],
        values='Boxes',
        aggfunc='sum'
    ).fillna(0)

    # --- Add TOTAL within each market (Chile + Peru) ---
    for market in pivot.columns.get_level_values(0).unique():
        # sum across CHILE + PERU (row-wise) for this market
        market_total = pivot[market].sum(axis=1)
        pivot[(market, 'TOTAL')] = market_total

    # --- Order columns within each market: CHILE, PERU, TOTAL ---
    new_order = []
    for market in sorted(pivot.columns.get_level_values(0).unique()):
        for country in ['CHILE', 'PERU', 'TOTAL']:
            col = (market, country)
            if col in pivot.columns:
                new_order.append(col)
    pivot = pivot[new_order]

    # --- Add season as top-level column ---
    pivot.columns = pd.MultiIndex.from_tuples([(s,) + col for col in pivot.columns])

    # --- Merge all seasons horizontally ---
    if merged_y is None:
        merged_y = pivot
    else:
        merged_y = pd.concat([merged_y, pivot], axis=1)

# 2️⃣ Sort and ensure numeric weeks
merged_y.index = pd.to_numeric(merged_y.index, errors='coerce')
merged_y = merged_y.sort_index().fillna(0).astype(int)

# 3️⃣ Build summary rows
idx = merged_y.index
current = merged_y.loc[idx == current_week].sum().to_frame().T
current.index = [f'Week {current_week + adjustment}']

prev_4 = merged_y.loc[(idx >= current_week - 3) & (idx <= current_week)].sum().to_frame().T
prev_4.index = ['Previous 4 Weeks Aggregate Total']

prev_8 = merged_y.loc[(idx >= current_week - 7) & (idx <= current_week)].sum().to_frame().T
prev_8.index = ['Previous 8 Weeks Aggregate Total']

ytd = merged_y.loc[(idx <= current_week)].sum().to_frame().T
ytd.index = ['Season Totals to Date']

# 4️⃣ Combine and format
summary = pd.concat([current, prev_4, prev_8, ytd])
summary = summary.fillna(0).astype(int)

# 5️⃣ Nicely formatted output (with commas)
summary.style.format("{:,}").set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'center')]},
    {'selector': 'td', 'props': [('text-align', 'center')]}
]).set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_93f8f th {
#   text-align: center;
# }
# #T_93f8f td {
#   text-align: center;
# }
# #T_93f8f_row0_col0, #T_93f8f_row0_col1, #T_93f8f_row0_col2, #T_93f8f_row0_col3, #T_93f8f_row0_col4, #T_93f8f_row0_col5, #T_93f8f_row0_col6, #T_93f8f_row0_col7, #T_93f8f_row0_col8, #T_93f8f_row0_col9, #T_93f8f_row0_col10, #T_93f8f_row0_col11, #T_93f8f_row0_col12, #T_93f8f_row0_col13, #T_93f8f_row0_col14, #T_93f8f_row0_col15, #T_93f8f_row1_col0, #T_93f8f_row1_col1, #T_93f8f_row1_col2, #T_93f8f_row1_col3, #T_93f8f_row1_col4, #T_93f8f_row1_col5, #T_93f8f_row1_col6, #T_93f8f_row1_col7, #T_93f8f_row1_col8, #T_93f8f_row1_col9, #T_93f8f_row1_col10, #T_93f8f_row1_col11, #T_93f8f_row1_col12, #T_93f8f_row1_col13, #T_93f8f_row1_col14, #T_93f8f_row1_col15, #T_93f8f_row2_col0, #T_93f8f_row2_col1, #T_93f8f_row2_col2, #T_93f8f_row2_col3, #T_93f8f_row2_col4, #T_93f8f_row2_col5, #T_93f8f_row2_col6, #T_93f8f_row2_col7, #T_93f8f_row2_col8, #T_93f8f_row2_col9, #T_93f8f_row2_col10, #T_93f8f_row2_col11, #T_93f8f_row2_col12, #T_93f8f_row2_col13, #T_93f8f_row2_col14, #T_93f8f_row2_col15, #T_93f8f_row3_col0, #T_93f8f_row3_col1, #T_93f8f_row3_col2, #T_93f8f_row3_col3, #T_93f8f_row3_col4, #T_93f8f_row3_col5, #T_93f8f_row3_col6, #T_93f8f_row3_col7, #T_93f8f_row3_col8, #T_93f8f_row3_col9, #T_93f8f_row3_col10, #T_93f8f_row3_col11, #T_93f8f_row3_col12, #T_93f8f_row3_col13, #T_93f8f_row3_col14, #T_93f8f_row3_col15 {
#   text-align: center;
# }
# </style>
# <table id="T_93f8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93f8f_level0_col0" class="col_heading level0 col0" colspan="4">2025-2026</th>
#       <th id="T_93f8f_level0_col4" class="col_heading level0 col4" colspan="6">2024-2025</th>
#       <th id="T_93f8f_level0_col10" class="col_heading level0 col10" colspan="6">2023-2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_93f8f_level1_col0" class="col_heading level1 col0" colspan="2">USA EAST COAST</th>
#       <th id="T_93f8f_level1_col2" class="col_heading level1 col2" colspan="2">USA WEST COAST</th>
#       <th id="T_93f8f_level1_col4" class="col_heading level1 col4" colspan="3">USA EAST COAST</th>
#       <th id="T_93f8f_level1_col7" class="col_heading level1 col7" colspan="3">USA WEST COAST</th>
#       <th id="T_93f8f_level1_col10" class="col_heading level1 col10" colspan="3">USA EAST COAST</th>
#       <th id="T_93f8f_level1_col13" class="col_heading level1 col13" colspan="3">USA WEST COAST</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_93f8f_level2_col0" class="col_heading level2 col0" >PERU</th>
#       <th id="T_93f8f_level2_col1" class="col_heading level2 col1" >TOTAL</th>
#       <th id="T_93f8f_level2_col2" class="col_heading level2 col2" >PERU</th>
#       <th id="T_93f8f_level2_col3" class="col_heading level2 col3" >TOTAL</th>
#       <th id="T_93f8f_level2_col4" class="col_heading level2 col4" >CHILE</th>
#       <th id="T_93f8f_level2_col5" class="col_heading level2 col5" >PERU</th>
#       <th id="T_93f8f_level2_col6" class="col_heading level2 col6" >TOTAL</th>
#       <th id="T_93f8f_level2_col7" class="col_heading level2 col7" >CHILE</th>
#       <th id="T_93f8f_level2_col8" class="col_heading level2 col8" >PERU</th>
#       <th id="T_93f8f_level2_col9" class="col_heading level2 col9" >TOTAL</th>
#       <th id="T_93f8f_level2_col10" class="col_heading level2 col10" >CHILE</th>
#       <th id="T_93f8f_level2_col11" class="col_heading level2 col11" >PERU</th>
#       <th id="T_93f8f_level2_col12" class="col_heading level2 col12" >TOTAL</th>
#       <th id="T_93f8f_level2_col13" class="col_heading level2 col13" >CHILE</th>
#       <th id="T_93f8f_level2_col14" class="col_heading level2 col14" >PERU</th>
#       <th id="T_93f8f_level2_col15" class="col_heading level2 col15" >TOTAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93f8f_level0_row0" class="row_heading level0 row0" >Week 43</th>
#       <td id="T_93f8f_row0_col0" class="data row0 col0" >446,640</td>
#       <td id="T_93f8f_row0_col1" class="data row0 col1" >446,640</td>
#       <td id="T_93f8f_row0_col2" class="data row0 col2" >96,074</td>
#       <td id="T_93f8f_row0_col3" class="data row0 col3" >96,074</td>
#       <td id="T_93f8f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_93f8f_row0_col5" class="data row0 col5" >553,210</td>
#       <td id="T_93f8f_row0_col6" class="data row0 col6" >553,210</td>
#       <td id="T_93f8f_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_93f8f_row0_col8" class="data row0 col8" >101,644</td>
#       <td id="T_93f8f_row0_col9" class="data row0 col9" >101,644</td>
#       <td id="T_93f8f_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_93f8f_row0_col11" class="data row0 col11" >1,081,817</td>
#       <td id="T_93f8f_row0_col12" class="data row0 col12" >1,081,817</td>
#       <td id="T_93f8f_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_93f8f_row0_col14" class="data row0 col14" >138,518</td>
#       <td id="T_93f8f_row0_col15" class="data row0 col15" >138,518</td>
#     </tr>
#     <tr>
#       <th id="T_93f8f_level0_row1" class="row_heading level0 row1" >Previous 4 Weeks Aggregate Total</th>
#       <td id="T_93f8f_row1_col0" class="data row1 col0" >742,623</td>
#       <td id="T_93f8f_row1_col1" class="data row1 col1" >742,623</td>
#       <td id="T_93f8f_row1_col2" class="data row1 col2" >144,193</td>
#       <td id="T_93f8f_row1_col3" class="data row1 col3" >144,193</td>
#       <td id="T_93f8f_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_93f8f_row1_col5" class="data row1 col5" >899,606</td>
#       <td id="T_93f8f_row1_col6" class="data row1 col6" >899,606</td>
#       <td id="T_93f8f_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_93f8f_row1_col8" class="data row1 col8" >176,649</td>
#       <td id="T_93f8f_row1_col9" class="data row1 col9" >176,649</td>
#       <td id="T_93f8f_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_93f8f_row1_col11" class="data row1 col11" >3,148,985</td>
#       <td id="T_93f8f_row1_col12" class="data row1 col12" >3,148,985</td>
#       <td id="T_93f8f_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_93f8f_row1_col14" class="data row1 col14" >331,100</td>
#       <td id="T_93f8f_row1_col15" class="data row1 col15" >331,100</td>
#     </tr>
#     <tr>
#       <th id="T_93f8f_level0_row2" class="row_heading level0 row2" >Previous 8 Weeks Aggregate Total</th>
#       <td id="T_93f8f_row2_col0" class="data row2 col0" >742,623</td>
#       <td id="T_93f8f_row2_col1" class="data row2 col1" >742,623</td>
#       <td id="T_93f8f_row2_col2" class="data row2 col2" >144,193</td>
#       <td id="T_93f8f_row2_col3" class="data row2 col3" >144,193</td>
#       <td id="T_93f8f_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_93f8f_row2_col5" class="data row2 col5" >899,606</td>
#       <td id="T_93f8f_row2_col6" class="data row2 col6" >899,606</td>
#       <td id="T_93f8f_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_93f8f_row2_col8" class="data row2 col8" >176,649</td>
#       <td id="T_93f8f_row2_col9" class="data row2 col9" >176,649</td>
#       <td id="T_93f8f_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_93f8f_row2_col11" class="data row2 col11" >3,148,985</td>
#       <td id="T_93f8f_row2_col12" class="data row2 col12" >3,148,985</td>
#       <td id="T_93f8f_row2_col13" class="data row2 col13" >0</td>
#       <td id="T_93f8f_row2_col14" class="data row2 col14" >331,100</td>
#       <td id="T_93f8f_row2_col15" class="data row2 col15" >331,100</td>
#     </tr>
#     <tr>
#       <th id="T_93f8f_level0_row3" class="row_heading level0 row3" >Season Totals to Date</th>
#       <td id="T_93f8f_row3_col0" class="data row3 col0" >742,623</td>
#       <td id="T_93f8f_row3_col1" class="data row3 col1" >742,623</td>
#       <td id="T_93f8f_row3_col2" class="data row3 col2" >144,193</td>
#       <td id="T_93f8f_row3_col3" class="data row3 col3" >144,193</td>
#       <td id="T_93f8f_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_93f8f_row3_col5" clas

# %% [markdown]
# <small><sup>*</sup>There is no column for Chile in the 2025-2026 Season because there are no recorded Grape imports from Chile so far this Season </small>

# %%
usa_simplified = usa.copy()
usa_simplified['Variety group'] = usa['Variety group'].apply(
    lambda x: 'RED' if 'RED' in x else ('WHITE' if 'WHITE' in x else 'OTHERS')
)

y= usa_simplified.groupby(['Season Week','Season','Market','Variety group']).agg({'Boxes':'sum'}).reset_index()

# %% [markdown]
# <div style="page-break-before:always"></div>

# %% [markdown]
# ## Weekly Imports by Variety Group/Color (Boxes)

# %%
# 1️⃣ Build merged_y
seasons = sorted(y['Season'].unique(),reverse=True)
merged_y = None

for s in seasons:
    temp = y[y['Season'] == s]

    # Pivot by Market and Variety group
    pivot = temp.pivot_table(
        index='Season Week',
        columns=['Market', 'Variety group'],
        values='Boxes',
        aggfunc='sum'
    ).fillna(0)

    # --- Add TOTAL within each market (sum across varieties) ---
    for market in pivot.columns.get_level_values(0).unique():
        market_total = pivot[market].sum(axis=1)
        pivot[(market, 'TOTAL')] = market_total

    # --- Order columns within each market: RED → WHITE → OTHERS → TOTAL ---
    desired_order = ['RED', 'WHITE', 'OTHERS', 'TOTAL']
    new_order = []
    for market in sorted(pivot.columns.get_level_values(0).unique()):
        varieties = [v for v in desired_order if (market, v) in pivot.columns]
        new_order.extend([(market, v) for v in varieties])
    pivot = pivot[new_order]

    # --- Add season as top-level column ---
    pivot.columns = pd.MultiIndex.from_tuples([(s,) + col for col in pivot.columns])

    # --- Merge all seasons horizontally ---
    if merged_y is None:
        merged_y = pivot
    else:
        merged_y = pd.concat([merged_y, pivot], axis=1)

# 2️⃣ Sort and ensure numeric weeks
merged_y.index = pd.to_numeric(merged_y.index, errors='coerce')
merged_y = merged_y.sort_index().fillna(0).astype(int)

# 3️⃣ Build summary rows
idx = merged_y.index
current = merged_y.loc[idx == current_week].sum().to_frame().T
current.index = [f'Week {current_week + adjustment}']

prev_4 = merged_y.loc[(idx >= current_week - 3) & (idx <= current_week)].sum().to_frame().T
prev_4.index = ['Previous 4 Weeks Aggregate Total']

prev_8 = merged_y.loc[(idx >= current_week - 7) & (idx <= current_week)].sum().to_frame().T
prev_8.index = ['Previous 8 Weeks Aggregate Total']

ytd = merged_y.loc[(idx <= current_week)].sum().to_frame().T
ytd.index = ['Season Totals to Date']

# 4️⃣ Combine and format
summary = pd.concat([current, prev_4, prev_8, ytd])
summary = summary.fillna(0).astype(int)

# 5️⃣ Nicely formatted output (with centered alignment)
summary.style.format("{:,}").set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'center')]},
    {'selector': 'td', 'props': [('text-align', 'center')]}
]).set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_58e17 th {
#   text-align: center;
# }
# #T_58e17 td {
#   text-align: center;
# }
# #T_58e17_row0_col0, #T_58e17_row0_col1, #T_58e17_row0_col2, #T_58e17_row0_col3, #T_58e17_row0_col4, #T_58e17_row0_col5, #T_58e17_row0_col6, #T_58e17_row0_col7, #T_58e17_row0_col8, #T_58e17_row0_col9, #T_58e17_row0_col10, #T_58e17_row0_col11, #T_58e17_row0_col12, #T_58e17_row0_col13, #T_58e17_row0_col14, #T_58e17_row0_col15, #T_58e17_row0_col16, #T_58e17_row0_col17, #T_58e17_row0_col18, #T_58e17_row0_col19, #T_58e17_row0_col20, #T_58e17_row0_col21, #T_58e17_row0_col22, #T_58e17_row0_col23, #T_58e17_row1_col0, #T_58e17_row1_col1, #T_58e17_row1_col2, #T_58e17_row1_col3, #T_58e17_row1_col4, #T_58e17_row1_col5, #T_58e17_row1_col6, #T_58e17_row1_col7, #T_58e17_row1_col8, #T_58e17_row1_col9, #T_58e17_row1_col10, #T_58e17_row1_col11, #T_58e17_row1_col12, #T_58e17_row1_col13, #T_58e17_row1_col14, #T_58e17_row1_col15, #T_58e17_row1_col16, #T_58e17_row1_col17, #T_58e17_row1_col18, #T_58e17_row1_col19, #T_58e17_row1_col20, #T_58e17_row1_col21, #T_58e17_row1_col22, #T_58e17_row1_col23, #T_58e17_row2_col0, #T_58e17_row2_col1, #T_58e17_row2_col2, #T_58e17_row2_col3, #T_58e17_row2_col4, #T_58e17_row2_col5, #T_58e17_row2_col6, #T_58e17_row2_col7, #T_58e17_row2_col8, #T_58e17_row2_col9, #T_58e17_row2_col10, #T_58e17_row2_col11, #T_58e17_row2_col12, #T_58e17_row2_col13, #T_58e17_row2_col14, #T_58e17_row2_col15, #T_58e17_row2_col16, #T_58e17_row2_col17, #T_58e17_row2_col18, #T_58e17_row2_col19, #T_58e17_row2_col20, #T_58e17_row2_col21, #T_58e17_row2_col22, #T_58e17_row2_col23, #T_58e17_row3_col0, #T_58e17_row3_col1, #T_58e17_row3_col2, #T_58e17_row3_col3, #T_58e17_row3_col4, #T_58e17_row3_col5, #T_58e17_row3_col6, #T_58e17_row3_col7, #T_58e17_row3_col8, #T_58e17_row3_col9, #T_58e17_row3_col10, #T_58e17_row3_col11, #T_58e17_row3_col12, #T_58e17_row3_col13, #T_58e17_row3_col14, #T_58e17_row3_col15, #T_58e17_row3_col16, #T_58e17_row3_col17, #T_58e17_row3_col18, #T_58e17_row3_col19, #T_58e17_row3_col20, #T_58e17_row3_col21, #T_58e17_row3_col22, #T_58e17_row3_col23 {
#   text-align: center;
# }
# </style>
# <table id="T_58e17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58e17_level0_col0" class="col_heading level0 col0" colspan="8">2025-2026</th>
#       <th id="T_58e17_level0_col8" class="col_heading level0 col8" colspan="8">2024-2025</th>
#       <th id="T_58e17_level0_col16" class="col_heading level0 col16" colspan="8">2023-2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_58e17_level1_col0" class="col_heading level1 col0" colspan="4">USA EAST COAST</th>
#       <th id="T_58e17_level1_col4" class="col_heading level1 col4" colspan="4">USA WEST COAST</th>
#       <th id="T_58e17_level1_col8" class="col_heading level1 col8" colspan="4">USA EAST COAST</th>
#       <th id="T_58e17_level1_col12" class="col_heading level1 col12" colspan="4">USA WEST COAST</th>
#       <th id="T_58e17_level1_col16" class="col_heading level1 col16" colspan="4">USA EAST COAST</th>
#       <th id="T_58e17_level1_col20" class="col_heading level1 col20" colspan="4">USA WEST COAST</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_58e17_level2_col0" class="col_heading level2 col0" >RED</th>
#       <th id="T_58e17_level2_col1" class="col_heading level2 col1" >WHITE</th>
#       <th id="T_58e17_level2_col2" class="col_heading level2 col2" >OTHERS</th>
#       <th id="T_58e17_level2_col3" class="col_heading level2 col3" >TOTAL</th>
#       <th id="T_58e17_level2_col4" class="col_heading level2 col4" >RED</th>
#       <th id="T_58e17_level2_col5" class="col_heading level2 col5" >WHITE</th>
#       <th id="T_58e17_level2_col6" class="col_heading level2 col6" >OTHERS</th>
#       <th id="T_58e17_level2_col7" class="col_heading level2 col7" >TOTAL</th>
#       <th id="T_58e17_level2_col8" class="col_heading level2 col8" >RED</th>
#       <th id="T_58e17_level2_col9" class="col_heading level2 col9" >WHITE</th>
#       <th id="T_58e17_level2_col10" class="col_heading level2 col10" >OTHERS</th>
#       <th id="T_58e17_level2_col11" class="col_heading level2 col11" >TOTAL</th>
#       <th id="T_58e17_level2_col12" class="col_heading level2 col12" >RED</th>
#       <th id="T_58e17_level2_col13" class="col_heading level2 col13" >WHITE</th>
#       <th id="T_58e17_level2_col14" class="col_heading level2 col14" >OTHERS</th>
#       <th id="T_58e17_level2_col15" class="col_heading level2 col15" >TOTAL</th>
#       <th id="T_58e17_level2_col16" class="col_heading level2 col16" >RED</th>
#       <th id="T_58e17_level2_col17" class="col_heading level2 col17" >WHITE</th>
#       <th id="T_58e17_level2_col18" class="col_heading level2 col18" >OTHERS</th>
#       <th id="T_58e17_level2_col19" class="col_heading level2 col19" >TOTAL</th>
#       <th id="T_58e17_level2_col20" class="col_heading level2 col20" >RED</th>
#       <th id="T_58e17_level2_col21" class="col_heading level2 col21" >WHITE</th>
#       <th id="T_58e17_level2_col22" class="col_heading level2 col22" >OTHERS</th>
#       <th id="T_58e17_level2_col23" class="col_heading level2 col23" >TOTAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58e17_level0_row0" class="row_heading level0 row0" >Week 43</th>
#       <td id="T_58e17_row0_col0" class="data row0 col0" >129,825</td>
#       <td id="T_58e17_row0_col1" class="data row0 col1" >279,643</td>
#       <td id="T_58e17_row0_col2" class="data row0 col2" >37,172</td>
#       <td id="T_58e17_row0_col3" class="data row0 col3" >446,640</td>
#       <td id="T_58e17_row0_col4" class="data row0 col4" >49,000</td>
#       <td id="T_58e17_row0_col5" class="data row0 col5" >28,959</td>
#       <td id="T_58e17_row0_col6" class="data row0 col6" >18,115</td>
#       <td id="T_58e17_row0_col7" class="data row0 col7" >96,074</td>
#       <td id="T_58e17_row0_col8" class="data row0 col8" >216,090</td>
#       <td id="T_58e17_row0_col9" class="data row0 col9" >323,936</td>
#       <td id="T_58e17_row0_col10" class="data row0 col10" >13,184</td>
#       <td id="T_58e17_row0_col11" class="data row0 col11" >553,210</td>
#       <td id="T_58e17_row0_col12" class="data row0 col12" >37,460</td>
#       <td id="T_58e17_row0_col13" class="data row0 col13" >55,540</td>
#       <td id="T_58e17_row0_col14" class="data row0 col14" >8,644</td>
#       <td id="T_58e17_row0_col15" class="data row0 col15" >101,644</td>
#       <td id="T_58e17_row0_col16" class="data row0 col16" >498,551</td>
#       <td id="T_58e17_row0_col17" class="data row0 col17" >480,511</td>
#       <td id="T_58e17_row0_col18" class="data row0 col18" >102,755</td>
#       <td id="T_58e17_row0_col19" class="data row0 col19" >1,081,817</td>
#       <td id="T_58e17_row0_col20" class="data row0 col20" >50,280</td>
#       <td id="T_58e17_row0_col21" class="data row0 col21" >48,100</td>
#       <td id="T_58e17_row0_col22" class="data row0 col22" >40,138</td>
#       <td id="T_58e17_row0_col23" class="data row0 col23" >138,518</td>
#     </tr>
#     <tr>
#       <th id="T_58e17_level0_row1" class="row_heading level0 row1" >Previous 4 Weeks Aggregate Total</th>
#       <td id="T_58e17_row1_col0" class="data row1 col0" >204,483</td>
#       <td id="T_58e17_row1_col1" class="data row1 col1" >500,968</td>
#       <td id="T_58e17_row1_col2" class="data row1 col2" >37,172</td>
#       <td id="T_58e17_row1_col3" class="data row1 col3" >742,623</td>
#       <td id="T_58e17_row1_col4" class="data row1 col4" >63,800</td>
#       <td id="T_58e17_row1_col5" class="data row1 col5" >55,868</td>
#       <td id="T_58e17_row1_col6" class="data row1 col6" >24,525</td>
#       <td id="T_58e17_row1_col7" class="data row1 col7" >144,193</td>
#       <td id="T_58e17_row1_col8" class="data row1 col8" >425,682</td>
#       <td id="T_58e17_row1_col9" class="data row1 col9" >455,140</td>
#       <td id="T_58e17_row1_col10" class="data row1 col10" >18,784</td>
#       <td id="T_58e17_row1_col11" class="data row1 col11" >899,606</td>
#       <td id="T_58e17_row1_col12" class="data row1 col12" >57,365</td>
#       <td id="T_58e17_row

# %%
white=usa[usa['Variety group'].str.contains('WHITE')]
white_g=white.groupby(['Season Week','Season','Market','Variety group']).agg({'Boxes':'sum'}).reset_index()

# %% [markdown]
# ## Weekly White Grape Imports

# %%
# 1️⃣ Build merged_y
seasons = sorted(white_g['Season'].unique(),reverse=True)
merged_y = None

for s in seasons:
    temp = white_g[white_g['Season'] == s]

    # Pivot by Market (we'll collapse Variety group immediately)
    pivot = temp.pivot_table(
        index='Season Week',
        columns=['Market', 'Variety group'],
        values='Boxes',
        aggfunc='sum'
    ).fillna(0)

    # --- Collapse Variety group so we only have Market totals ---
    pivot = pivot.groupby(level=0, axis=1).sum()

    # --- Add TOTAL for the whole season (sum of all markets) ---
    pivot['TOTAL'] = pivot.sum(axis=1)

    # --- Wrap columns in a MultiIndex with Season as top level ---
    pivot.columns = pd.MultiIndex.from_tuples([(s, c) for c in pivot.columns])

    # --- Merge all seasons horizontally ---
    if merged_y is None:
        merged_y = pivot
    else:
        merged_y = pd.concat([merged_y, pivot], axis=1)

# 2️⃣ Sort and ensure numeric weeks
merged_y.index = pd.to_numeric(merged_y.index, errors='coerce')
merged_y = merged_y.sort_index().fillna(0).astype(int)

# 3️⃣ Build summary rows
idx = merged_y.index
current = merged_y.loc[idx == current_week].sum().to_frame().T
current.index = [f'Week {current_week + adjustment}']

prev_4 = merged_y.loc[(idx >= current_week - 3) & (idx <= current_week)].sum().to_frame().T
prev_4.index = ['Previous 4 Weeks Aggregate Total']

prev_8 = merged_y.loc[(idx >= current_week - 7) & (idx <= current_week)].sum().to_frame().T
prev_8.index = ['Previous 8 Weeks Aggregate Total']

ytd = merged_y.loc[(idx <= current_week)].sum().to_frame().T
ytd.index = ['Season Totals to Date']

# 4️⃣ Combine and format
summary = pd.concat([current, prev_4, prev_8, ytd])
summary = summary.fillna(0).astype(int)

# 5️⃣ Nicely formatted output
from IPython.display import display
display(
    summary.style.format("{:,}")
    .set_table_styles([
        {'selector': 'th', 'props': [('text-align', 'center')]},
        {'selector': 'td', 'props': [('text-align', 'center')]}
    ])
    .set_properties(**{'text-align': 'center'})
)
# Out:
# <style type="text/css">
# #T_85b2e th {
#   text-align: center;
# }
# #T_85b2e td {
#   text-align: center;
# }
# #T_85b2e_row0_col0, #T_85b2e_row0_col1, #T_85b2e_row0_col2, #T_85b2e_row0_col3, #T_85b2e_row0_col4, #T_85b2e_row0_col5, #T_85b2e_row0_col6, #T_85b2e_row0_col7, #T_85b2e_row0_col8, #T_85b2e_row1_col0, #T_85b2e_row1_col1, #T_85b2e_row1_col2, #T_85b2e_row1_col3, #T_85b2e_row1_col4, #T_85b2e_row1_col5, #T_85b2e_row1_col6, #T_85b2e_row1_col7, #T_85b2e_row1_col8, #T_85b2e_row2_col0, #T_85b2e_row2_col1, #T_85b2e_row2_col2, #T_85b2e_row2_col3, #T_85b2e_row2_col4, #T_85b2e_row2_col5, #T_85b2e_row2_col6, #T_85b2e_row2_col7, #T_85b2e_row2_col8, #T_85b2e_row3_col0, #T_85b2e_row3_col1, #T_85b2e_row3_col2, #T_85b2e_row3_col3, #T_85b2e_row3_col4, #T_85b2e_row3_col5, #T_85b2e_row3_col6, #T_85b2e_row3_col7, #T_85b2e_row3_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_85b2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85b2e_level0_col0" class="col_heading level0 col0" colspan="3">2025-2026</th>
#       <th id="T_85b2e_level0_col3" class="col_heading level0 col3" colspan="3">2024-2025</th>
#       <th id="T_85b2e_level0_col6" class="col_heading level0 col6" colspan="3">2023-2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_85b2e_level1_col0" class="col_heading level1 col0" >USA EAST COAST</th>
#       <th id="T_85b2e_level1_col1" class="col_heading level1 col1" >USA WEST COAST</th>
#       <th id="T_85b2e_level1_col2" class="col_heading level1 col2" >TOTAL</th>
#       <th id="T_85b2e_level1_col3" class="col_heading level1 col3" >USA EAST COAST</th>
#       <th id="T_85b2e_level1_col4" class="col_heading level1 col4" >USA WEST COAST</th>
#       <th id="T_85b2e_level1_col5" class="col_heading level1 col5" >TOTAL</th>
#       <th id="T_85b2e_level1_col6" class="col_heading level1 col6" >USA EAST COAST</th>
#       <th id="T_85b2e_level1_col7" class="col_heading level1 col7" >USA WEST COAST</th>
#       <th id="T_85b2e_level1_col8" class="col_heading level1 col8" >TOTAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85b2e_level0_row0" class="row_heading level0 row0" >Week 43</th>
#       <td id="T_85b2e_row0_col0" class="data row0 col0" >279,643</td>
#       <td id="T_85b2e_row0_col1" class="data row0 col1" >28,959</td>
#       <td id="T_85b2e_row0_col2" class="data row0 col2" >308,602</td>
#       <td id="T_85b2e_row0_col3" class="data row0 col3" >323,936</td>
#       <td id="T_85b2e_row0_col4" class="data row0 col4" >55,540</td>
#       <td id="T_85b2e_row0_col5" class="data row0 col5" >379,476</td>
#       <td id="T_85b2e_row0_col6" class="data row0 col6" >480,511</td>
#       <td id="T_85b2e_row0_col7" class="data row0 col7" >48,100</td>
#       <td id="T_85b2e_row0_col8" class="data row0 col8" >528,611</td>
#     </tr>
#     <tr>
#       <th id="T_85b2e_level0_row1" class="row_heading level0 row1" >Previous 4 Weeks Aggregate Total</th>
#       <td id="T_85b2e_row1_col0" class="data row1 col0" >500,968</td>
#       <td id="T_85b2e_row1_col1" class="data row1 col1" >55,868</td>
#       <td id="T_85b2e_row1_col2" class="data row1 col2" >556,836</td>
#       <td id="T_85b2e_row1_col3" class="data row1 col3" >455,140</td>
#       <td id="T_85b2e_row1_col4" class="data row1 col4" >107,440</td>
#       <td id="T_85b2e_row1_col5" class="data row1 col5" >562,580</td>
#       <td id="T_85b2e_row1_col6" class="data row1 col6" >1,305,299</td>
#       <td id="T_85b2e_row1_col7" class="data row1 col7" >119,800</td>
#       <td id="T_85b2e_row1_col8" class="data row1 col8" >1,425,099</td>
#     </tr>
#     <tr>
#       <th id="T_85b2e_level0_row2" class="row_heading level0 row2" >Previous 8 Weeks Aggregate Total</th>
#       <td id="T_85b2e_row2_col0" class="data row2 col0" >500,968</td>
#       <td id="T_85b2e_row2_col1" class="data row2 col1" >55,868</td>
#       <td id="T_85b2e_row2_col2" class="data row2 col2" >556,836</td>
#       <td id="T_85b2e_row2_col3" class="data row2 col3" >455,140</td>
#       <td id="T_85b2e_row2_col4" class="data row2 col4" >107,440</td>
#       <td id="T_85b2e_row2_col5" class="data row2 col5" >562,580</td>
#       <td id="T_85b2e_row2_col6" class="data row2 col6" >1,305,299</td>
#       <td id="T_85b2e_row2_col7" class="data row2 col7" >119,800</td>
#       <td id="T_85b2e_row2_col8" class="data row2 col8" >1,425,099</td>
#     </tr>
#     <tr>
#       <th id="T_85b2e_level0_row3" class="row_heading level0 row3" >Season Totals to Date</th>
#       <td id="T_85b2e_row3_col0" class="data row3 col0" >500,968</td>
#       <td id="T_85b2e_row3_col1" class="data row3 col1" >55,868</td>
#       <td id="T_85b2e_row3_col2" class="data row3 col2" >556,836</td>
#       <td id="T_85b2e_row3_col3" class="data row3 col3" >455,140</td>
#       <td id="T_85b2e_row3_col4" class="data row3 col4" >107,440</td>
#       <td id="T_85b2e_row3_col5" class="data row3 col5" >562,580</td>
#       <td id="T_85b2e_row3_col6" class="data row3 col6" >1,305,299</td>
#       <td id="T_85b2e_row3_col7" class="data row3 col7" >119,800</td>
#       <td id="T_85b2e_row3_col8" class="data row3 col8" >1,425,099</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Weekly Red Grape Imports

# %%
r=usa[usa['Variety group'].str.contains('RED')]
r=r.groupby(['Season Week','Season','Market','Variety group']).agg({'Boxes':'sum'}).reset_index()

# %%
# 1️⃣ Build merged_y
seasons = sorted(r['Season'].unique(),reverse=True)
merged_y = None

for s in seasons:
    temp = r[r['Season'] == s]

    # Pivot by Market and Variety group
    pivot = temp.pivot_table(
        index='Season Week',
        columns=['Market', 'Variety group'],
        values='Boxes',
        aggfunc='sum'
    ).fillna(0)
    
    # --- Add TOTAL within each market (sum across varieties) ---
    for market in pivot.columns.get_level_values(0).unique():
        market_total = pivot[market].sum(axis=1)
        pivot[(market, 'TOTAL')] = market_total

    # --- Order columns within each market: RED SEEDLESS → RED SEEDED → TOTAL ---
    desired_order = ['RED SEEDLESS', 'RED SEEDED', 'TOTAL']
    new_order = []
    for market in sorted(pivot.columns.get_level_values(0).unique()):
        varieties = [v for v in desired_order if (market, v) in pivot.columns]
        new_order.extend([(market, v) for v in varieties])
    pivot = pivot[new_order]

    # --- Add season as top-level column ---
    pivot.columns = pd.MultiIndex.from_tuples([(s,) + col for col in pivot.columns])

    # --- Merge all seasons horizontally ---
    if merged_y is None:
        merged_y = pivot
    else:
        merged_y = pd.concat([merged_y, pivot], axis=1)

# 2️⃣ Sort and ensure numeric weeks
merged_y.index = pd.to_numeric(merged_y.index, errors='coerce')
merged_y = merged_y.sort_index().fillna(0).astype(int)

# 3️⃣ Build summary rows
idx = merged_y.index
current = merged_y.loc[idx == current_week].sum().to_frame().T
current.index = [f'Week {current_week + adjustment}']

prev_4 = merged_y.loc[(idx >= current_week - 3) & (idx <= current_week)].sum().to_frame().T
prev_4.index = ['Previous 4 Weeks Aggregate Total']

prev_8 = merged_y.loc[(idx >= current_week - 7) & (idx <= current_week)].sum().to_frame().T
prev_8.index = ['Previous 8 Weeks Aggregate Total']

ytd = merged_y.loc[(idx <= current_week)].sum().to_frame().T
ytd.index = ['Season Totals to Date']

# 4️⃣ Combine and format
summary = pd.concat([current, prev_4, prev_8, ytd])
summary = summary.fillna(0).astype(int)

# 5️⃣ Nicely formatted output (with centered alignment)
summary.style.format("{:,}").set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'center')]},
    {'selector': 'td', 'props': [('text-align', 'center')]}
]).set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_e9065 th {
#   text-align: center;
# }
# #T_e9065 td {
#   text-align: center;
# }
# #T_e9065_row0_col0, #T_e9065_row0_col1, #T_e9065_row0_col2, #T_e9065_row0_col3, #T_e9065_row0_col4, #T_e9065_row0_col5, #T_e9065_row0_col6, #T_e9065_row0_col7, #T_e9065_row0_col8, #T_e9065_row0_col9, #T_e9065_row0_col10, #T_e9065_row0_col11, #T_e9065_row0_col12, #T_e9065_row0_col13, #T_e9065_row0_col14, #T_e9065_row0_col15, #T_e9065_row0_col16, #T_e9065_row0_col17, #T_e9065_row1_col0, #T_e9065_row1_col1, #T_e9065_row1_col2, #T_e9065_row1_col3, #T_e9065_row1_col4, #T_e9065_row1_col5, #T_e9065_row1_col6, #T_e9065_row1_col7, #T_e9065_row1_col8, #T_e9065_row1_col9, #T_e9065_row1_col10, #T_e9065_row1_col11, #T_e9065_row1_col12, #T_e9065_row1_col13, #T_e9065_row1_col14, #T_e9065_row1_col15, #T_e9065_row1_col16, #T_e9065_row1_col17, #T_e9065_row2_col0, #T_e9065_row2_col1, #T_e9065_row2_col2, #T_e9065_row2_col3, #T_e9065_row2_col4, #T_e9065_row2_col5, #T_e9065_row2_col6, #T_e9065_row2_col7, #T_e9065_row2_col8, #T_e9065_row2_col9, #T_e9065_row2_col10, #T_e9065_row2_col11, #T_e9065_row2_col12, #T_e9065_row2_col13, #T_e9065_row2_col14, #T_e9065_row2_col15, #T_e9065_row2_col16, #T_e9065_row2_col17, #T_e9065_row3_col0, #T_e9065_row3_col1, #T_e9065_row3_col2, #T_e9065_row3_col3, #T_e9065_row3_col4, #T_e9065_row3_col5, #T_e9065_row3_col6, #T_e9065_row3_col7, #T_e9065_row3_col8, #T_e9065_row3_col9, #T_e9065_row3_col10, #T_e9065_row3_col11, #T_e9065_row3_col12, #T_e9065_row3_col13, #T_e9065_row3_col14, #T_e9065_row3_col15, #T_e9065_row3_col16, #T_e9065_row3_col17 {
#   text-align: center;
# }
# </style>
# <table id="T_e9065">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9065_level0_col0" class="col_heading level0 col0" colspan="6">2025-2026</th>
#       <th id="T_e9065_level0_col6" class="col_heading level0 col6" colspan="6">2024-2025</th>
#       <th id="T_e9065_level0_col12" class="col_heading level0 col12" colspan="6">2023-2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_e9065_level1_col0" class="col_heading level1 col0" colspan="3">USA EAST COAST</th>
#       <th id="T_e9065_level1_col3" class="col_heading level1 col3" colspan="3">USA WEST COAST</th>
#       <th id="T_e9065_level1_col6" class="col_heading level1 col6" colspan="3">USA EAST COAST</th>
#       <th id="T_e9065_level1_col9" class="col_heading level1 col9" colspan="3">USA WEST COAST</th>
#       <th id="T_e9065_level1_col12" class="col_heading level1 col12" colspan="3">USA EAST COAST</th>
#       <th id="T_e9065_level1_col15" class="col_heading level1 col15" colspan="3">USA WEST COAST</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_e9065_level2_col0" class="col_heading level2 col0" >RED SEEDLESS</th>
#       <th id="T_e9065_level2_col1" class="col_heading level2 col1" >RED SEEDED</th>
#       <th id="T_e9065_level2_col2" class="col_heading level2 col2" >TOTAL</th>
#       <th id="T_e9065_level2_col3" class="col_heading level2 col3" >RED SEEDLESS</th>
#       <th id="T_e9065_level2_col4" class="col_heading level2 col4" >RED SEEDED</th>
#       <th id="T_e9065_level2_col5" class="col_heading level2 col5" >TOTAL</th>
#       <th id="T_e9065_level2_col6" class="col_heading level2 col6" >RED SEEDLESS</th>
#       <th id="T_e9065_level2_col7" class="col_heading level2 col7" >RED SEEDED</th>
#       <th id="T_e9065_level2_col8" class="col_heading level2 col8" >TOTAL</th>
#       <th id="T_e9065_level2_col9" class="col_heading level2 col9" >RED SEEDLESS</th>
#       <th id="T_e9065_level2_col10" class="col_heading level2 col10" >RED SEEDED</th>
#       <th id="T_e9065_level2_col11" class="col_heading level2 col11" >TOTAL</th>
#       <th id="T_e9065_level2_col12" class="col_heading level2 col12" >RED SEEDLESS</th>
#       <th id="T_e9065_level2_col13" class="col_heading level2 col13" >RED SEEDED</th>
#       <th id="T_e9065_level2_col14" class="col_heading level2 col14" >TOTAL</th>
#       <th id="T_e9065_level2_col15" class="col_heading level2 col15" >RED SEEDLESS</th>
#       <th id="T_e9065_level2_col16" class="col_heading level2 col16" >RED SEEDED</th>
#       <th id="T_e9065_level2_col17" class="col_heading level2 col17" >TOTAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9065_level0_row0" class="row_heading level0 row0" >Week 43</th>
#       <td id="T_e9065_row0_col0" class="data row0 col0" >102,105</td>
#       <td id="T_e9065_row0_col1" class="data row0 col1" >27,720</td>
#       <td id="T_e9065_row0_col2" class="data row0 col2" >129,825</td>
#       <td id="T_e9065_row0_col3" class="data row0 col3" >46,840</td>
#       <td id="T_e9065_row0_col4" class="data row0 col4" >2,160</td>
#       <td id="T_e9065_row0_col5" class="data row0 col5" >49,000</td>
#       <td id="T_e9065_row0_col6" class="data row0 col6" >194,954</td>
#       <td id="T_e9065_row0_col7" class="data row0 col7" >21,136</td>
#       <td id="T_e9065_row0_col8" class="data row0 col8" >216,090</td>
#       <td id="T_e9065_row0_col9" class="data row0 col9" >35,300</td>
#       <td id="T_e9065_row0_col10" class="data row0 col10" >2,160</td>
#       <td id="T_e9065_row0_col11" class="data row0 col11" >37,460</td>
#       <td id="T_e9065_row0_col12" class="data row0 col12" >472,891</td>
#       <td id="T_e9065_row0_col13" class="data row0 col13" >25,660</td>
#       <td id="T_e9065_row0_col14" class="data row0 col14" >498,551</td>
#       <td id="T_e9065_row0_col15" class="data row0 col15" >50,280</td>
#       <td id="T_e9065_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_e9065_row0_col17" class="data row0 col17" >50,280</td>
#     </tr>
#     <tr>
#       <th id="T_e9065_level0_row1" class="row_heading level0 row1" >Previous 4 Weeks Aggregate Total</th>
#       <td id="T_e9065_row1_col0" class="data row1 col0" >153,363</td>
#       <td id="T_e9065_row1_col1" class="data row1 col1" >51,120</td>
#       <td id="T_e9065_row1_col2" class="data row1 col2" >204,483</td>
#       <td id="T_e9065_row1_col3" class="data row1 col3" >59,840</td>
#       <td id="T_e9065_row1_col4" class="data row1 col4" >3,960</td>
#       <td id="T_e9065_row1_col5" class="data row1 col5" >63,800</td>
#       <td id="T_e9065_row1_col6" class="data row1 col6" >330,266</td>
#       <td id="T_e9065_row1_col7" class="data row1 col7" >95,416</td>
#       <td id="T_e9065_row1_col8" class="data row1 col8" >425,682</td>
#       <td id="T_e9065_row1_col9" class="data row1 col9" >48,725</td>
#       <td id="T_e9065_row1_col10" class="data row1 col10" >8,640</td>
#       <td id="T_e9065_row1_col11" class="data row1 col11" >57,365</td>
#       <td id="T_e9065_row1_col12" class="data row1 col12" >1,504,906</td>
#       <td id="T_e9065_row1_col13" class="data row1 col13" >139,308</td>
#       <td id="T_e9065_row1_col14" class="data row1 col14" >1,644,214</td>
#       <td id="T_e9065_row1_col15" class="data row1 col15" >135,116</td>
#       <td id="T_e9065_row1_col16" class="data row1 col16" >6,480</td>
#       <td id="T_e9065_row1_col17" class="data row1 col17" >141,596</td>
#     </tr>
#     <tr>
#       <th id="T_e9065_level0_row2" class="row_heading level0 row2" >Previous 8 Weeks Aggregate Total</th>
#       <td id="T_e9065_row2_col0" class="data row2 col0" >153,363</td>
#       <td id="T_e9065_row2_col1" class="data row2 col1" >51,120</td>
#       <td id="T_e9065_row2_col2" class="data row2 col2" >204,483</td>
#       <td id="T_e9065_row2_col3" class="data row2 col3" >59,840</td>
#       <td id="T_e9065_row2_col4" class="data row2 col4" >3,960</td>
#       <td id="T_e9065_row2_col5" class="data row2 col5" >63,800</td>
#       <td id="T_e9065_row2_col6" class="data row2 col6" >330,266</td>
#       <td id="T_e9065_row2_col7" class="data row2 col7" >95,416</td>
#       <td id="T_e9065_row2_col8" class="data row2 col8" >425,682</td>
#       <td id="T_e9065_row2_col9" class="data row2 col9" >48,725</td>
#       <td id="T_e9065_row2_col10" class="data row2 col10" >8,640</td>
#       <td id="T_e9065_row2_col11" class="data row2 col11" >57,365</td>
#       <td id="T_e9065_row2_col12" class="data row2 col12" >1,5

# %%
black=usa[usa['Variety group'].str.contains('BLACK')]
black=black.groupby(['Season Week','Season','Market','Variety group']).agg({'Boxes':'sum'}).reset_index()

# %% [markdown]
# <div style="page-break-before:always"></div>

# %% [markdown]
# ## Weekly Black Grape Imports

# %%
# 1️⃣ Build merged_y
seasons = sorted(black['Season'].unique(),reverse=True)
merged_y = None

for s in seasons:
    temp = black[black['Season'] == s]

    # Pivot by Market and Variety group
    pivot = temp.pivot_table(
        index='Season Week',
        columns=['Market', 'Variety group'],
        values='Boxes',
        aggfunc='sum'
    ).fillna(0)

    # --- Collapse Variety group level so only Market remains ---
    pivot = pivot.groupby(level=0, axis=1).sum()

    # --- Add TOTAL across all markets for the season ---
    pivot['TOTAL'] = pivot.sum(axis=1)

    # --- Add season as top-level column ---
    pivot.columns = pd.MultiIndex.from_tuples([(s, col) for col in pivot.columns])

    # --- Merge all seasons horizontally ---
    if merged_y is None:
        merged_y = pivot
    else:
        merged_y = pd.concat([merged_y, pivot], axis=1)

# 2️⃣ Sort and ensure numeric week index
merged_y.index = pd.to_numeric(merged_y.index, errors='coerce')
merged_y = merged_y.sort_index().fillna(0).astype(int)

# 3️⃣ Build summary rows
idx = merged_y.index

current = merged_y.loc[idx == current_week].sum().to_frame().T
current.index = [f'Week {current_week + adjustment}']

prev_4 = merged_y.loc[(idx >= current_week - 3) & (idx <= current_week)].sum().to_frame().T
prev_4.index = ['Previous 4 Weeks Aggregate Total']

prev_8 = merged_y.loc[(idx >= current_week - 7) & (idx <= current_week)].sum().to_frame().T
prev_8.index = ['Previous 8 Weeks Aggregate Total']

ytd = merged_y.loc[(idx <= current_week)].sum().to_frame().T
ytd.index = ['Season Totals to Date']

# 4️⃣ Combine and format final summary
summary = pd.concat([current, prev_4, prev_8, ytd])
summary = summary.fillna(0).astype(int)

# 5️⃣ Nicely formatted display (centered)
from IPython.display import display
display(
    summary.style.format("{:,}")
    .set_table_styles([
        {'selector': 'th', 'props': [('text-align', 'center')]},
        {'selector': 'td', 'props': [('text-align', 'center')]}
    ])
    .set_properties(**{'text-align': 'center'})
)
# Out:
# <style type="text/css">
# #T_88867 th {
#   text-align: center;
# }
# #T_88867 td {
#   text-align: center;
# }
# #T_88867_row0_col0, #T_88867_row0_col1, #T_88867_row0_col2, #T_88867_row0_col3, #T_88867_row0_col4, #T_88867_row0_col5, #T_88867_row0_col6, #T_88867_row0_col7, #T_88867_row0_col8, #T_88867_row1_col0, #T_88867_row1_col1, #T_88867_row1_col2, #T_88867_row1_col3, #T_88867_row1_col4, #T_88867_row1_col5, #T_88867_row1_col6, #T_88867_row1_col7, #T_88867_row1_col8, #T_88867_row2_col0, #T_88867_row2_col1, #T_88867_row2_col2, #T_88867_row2_col3, #T_88867_row2_col4, #T_88867_row2_col5, #T_88867_row2_col6, #T_88867_row2_col7, #T_88867_row2_col8, #T_88867_row3_col0, #T_88867_row3_col1, #T_88867_row3_col2, #T_88867_row3_col3, #T_88867_row3_col4, #T_88867_row3_col5, #T_88867_row3_col6, #T_88867_row3_col7, #T_88867_row3_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_88867">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88867_level0_col0" class="col_heading level0 col0" colspan="3">2025-2026</th>
#       <th id="T_88867_level0_col3" class="col_heading level0 col3" colspan="3">2024-2025</th>
#       <th id="T_88867_level0_col6" class="col_heading level0 col6" colspan="3">2023-2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_88867_level1_col0" class="col_heading level1 col0" >USA EAST COAST</th>
#       <th id="T_88867_level1_col1" class="col_heading level1 col1" >USA WEST COAST</th>
#       <th id="T_88867_level1_col2" class="col_heading level1 col2" >TOTAL</th>
#       <th id="T_88867_level1_col3" class="col_heading level1 col3" >USA EAST COAST</th>
#       <th id="T_88867_level1_col4" class="col_heading level1 col4" >USA WEST COAST</th>
#       <th id="T_88867_level1_col5" class="col_heading level1 col5" >TOTAL</th>
#       <th id="T_88867_level1_col6" class="col_heading level1 col6" >USA EAST COAST</th>
#       <th id="T_88867_level1_col7" class="col_heading level1 col7" >USA WEST COAST</th>
#       <th id="T_88867_level1_col8" class="col_heading level1 col8" >TOTAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88867_level0_row0" class="row_heading level0 row0" >Week 43</th>
#       <td id="T_88867_row0_col0" class="data row0 col0" >20,900</td>
#       <td id="T_88867_row0_col1" class="data row0 col1" >13,600</td>
#       <td id="T_88867_row0_col2" class="data row0 col2" >34,500</td>
#       <td id="T_88867_row0_col3" class="data row0 col3" >5,200</td>
#       <td id="T_88867_row0_col4" class="data row0 col4" >1,600</td>
#       <td id="T_88867_row0_col5" class="data row0 col5" >6,800</td>
#       <td id="T_88867_row0_col6" class="data row0 col6" >50,600</td>
#       <td id="T_88867_row0_col7" class="data row0 col7" >24,200</td>
#       <td id="T_88867_row0_col8" class="data row0 col8" >74,800</td>
#     </tr>
#     <tr>
#       <th id="T_88867_level0_row1" class="row_heading level0 row1" >Previous 4 Weeks Aggregate Total</th>
#       <td id="T_88867_row1_col0" class="data row1 col0" >20,900</td>
#       <td id="T_88867_row1_col1" class="data row1 col1" >17,000</td>
#       <td id="T_88867_row1_col2" class="data row1 col2" >37,900</td>
#       <td id="T_88867_row1_col3" class="data row1 col3" >10,800</td>
#       <td id="T_88867_row1_col4" class="data row1 col4" >3,200</td>
#       <td id="T_88867_row1_col5" class="data row1 col5" >14,000</td>
#       <td id="T_88867_row1_col6" class="data row1 col6" >88,360</td>
#       <td id="T_88867_row1_col7" class="data row1 col7" >32,300</td>
#       <td id="T_88867_row1_col8" class="data row1 col8" >120,660</td>
#     </tr>
#     <tr>
#       <th id="T_88867_level0_row2" class="row_heading level0 row2" >Previous 8 Weeks Aggregate Total</th>
#       <td id="T_88867_row2_col0" class="data row2 col0" >20,900</td>
#       <td id="T_88867_row2_col1" class="data row2 col1" >17,000</td>
#       <td id="T_88867_row2_col2" class="data row2 col2" >37,900</td>
#       <td id="T_88867_row2_col3" class="data row2 col3" >10,800</td>
#       <td id="T_88867_row2_col4" class="data row2 col4" >3,200</td>
#       <td id="T_88867_row2_col5" class="data row2 col5" >14,000</td>
#       <td id="T_88867_row2_col6" class="data row2 col6" >88,360</td>
#       <td id="T_88867_row2_col7" class="data row2 col7" >32,300</td>
#       <td id="T_88867_row2_col8" class="data row2 col8" >120,660</td>
#     </tr>
#     <tr>
#       <th id="T_88867_level0_row3" class="row_heading level0 row3" >Season Totals to Date</th>
#       <td id="T_88867_row3_col0" class="data row3 col0" >20,900</td>
#       <td id="T_88867_row3_col1" class="data row3 col1" >17,000</td>
#       <td id="T_88867_row3_col2" class="data row3 col2" >37,900</td>
#       <td id="T_88867_row3_col3" class="data row3 col3" >10,800</td>
#       <td id="T_88867_row3_col4" class="data row3 col4" >3,200</td>
#       <td id="T_88867_row3_col5" class="data row3 col5" >14,000</td>
#       <td id="T_88867_row3_col6" class="data row3 col6" >88,360</td>
#       <td id="T_88867_row3_col7" class="data row3 col7" >32,300</td>
#       <td id="T_88867_row3_col8" class="data row3 col8" >120,660</td>
#     </tr>
#   </tbody>
# </table>
